# %%
from oa_tool.downloader import OpenAlexDownloader

oa_downloader = OpenAlexDownloader(
    2022,
    2023,
    concepts=["C132651083"],
    email="youremail@...",
    has_abstract=True,
    out_path="../data/open_alex/"
)

# %%
overall_stats = oa_downloader.download(only_overall_stats=True)

# %%
overall_stats = oa_downloader.download()
# Out:
# 12512/12512 for year 2017
# 13857/13857 for year 2018
# 13610/13611 for year 2019
# 11654/11654 for year 2020
# 10090/10090 for year 2021
# 9572/9571 for year 2022
# 4183/4183 for year 2023

# %%
overall_stats
# missing 1 article: 2014, 2019, 2022
# Out:
#     year  count
# 0   2000   1720
# 1   2001   2377
# 2   2002   2194
# 3   2003   2596
# 4   2004   2724
# 5   2005   2957
# 6   2006   3492
# 7   2007   4662
# 8   2008   5687
# 9   2009   9023
# 10  2010   8888
# 11  2011   8489
# 12  2012  10235
# 13  2013  11274
# 14  2014  11872
# 15  2015  12007
# 16  2016  12602
# 17  2017  12509
# 18  2018  13853
# 19  2019  13604
# 20  2020  11646
# 21  2021  10078
# 22  2022   9577
# 23  2023   4183

# %%
# assertion error: 2014
oa_downloader_old = OpenAlexDownloader(
    1950,
    1999,
    concepts=["C132651083"],
    email="roxanne.elbaff@dlr.de",
    has_abstract=False,
    out_path="../data/open_alex/"
)
overall_stats_old = oa_downloader_old.download()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...
